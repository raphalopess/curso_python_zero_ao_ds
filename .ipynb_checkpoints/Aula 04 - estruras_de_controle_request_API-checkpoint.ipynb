# %%
import requests as r
import pandas as pd

dataset = pd.DataFrame()


i = 1
while True:
    print( 'page:{}'. format( i ) )
    url = 'https://jobs.github.com/positions.json?description=python&full_time=true&page={}'
    response = r.request('GET', url)

    if response.json() != []:
        data = response.json()[0]
        df = pd.DataFrame(data, index = [0])

        print(df [['id', 'type']] )

        dataset = pd.concat([dataset,df], axis = 0)

        i = i + 1
# Out:
# page:1
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-4-abbb18cb3eeb> in <module>
#      11     response = r.request('GET', url)
#      12
# ---> 13     if response.json() != []:
#      14         data = response.json()[0]
#      15         df = pd.DataFrame(data, index = [0])
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
# ...

# %%
# 2.	Adicione as seguintes informações ao imóvel:
# - Nome da rua
# 'road': '61st Avenue South'

# - Numero do imóvel
# 'house_number': '10012'

# - Nome do bairro
# 'house_number': '10012'

# - Nome da cidade
# 'house_number': '10012'

# - Nome do estado
# 'state': 'Washington'

import pandas as pd

df = pd.read_csv(r"C:\Users\User\datasets\kc_house_data.csv")

from geopy.geocoders import Nominatim

# Initialize Nominatim API
geolocator = Nominatim( user_agent='geoapiExercises' )

# Selecionando lat e long para informações do local

response = geolocator.reverse( '47.5112,-122.257' )

# Visualização de todos os elementos pelo dicionario
response.raw

# Visualização definindo qual elemento do dicionario

print( response.raw['address']['road'] )
print( response.raw['address']['house_number'] )
print( response.raw['address']['neighbourhood'] )
print( response.raw['address']['city'] )
print( response.raw['address']['county'] )
print( response.raw['address']['state'] )
# Out:
# 61st Avenue South
# 10012
# Rainier Beach
# Seattle
# King County
# Washington

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\User\datasets\kc_house_data.csv")

# Criando linhas vazias para add no dataframe

df['road'] = 'NA'
df['house_number'] = 'NA'
df['city'] = 'NA'
df['county'] = 'NA'
df['state'] = 'NA'

df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  zipcode      lat     long  \
# 0      5650     1.0           0     0  ...    98178  47.5112 -122.257
# 1      7242     2.0           0     0  ...    98125  47.7210 -122.319
# 2     10000     1.0           0     0  ...    98028  47.7379 -122.233
# 3      5000     1.0           0     0  ...    98136  47.5208 -122.393
# 4      8080     1.0           0     0  ...    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  road  house_number  city  county  state
# ...
